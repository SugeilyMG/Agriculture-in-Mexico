# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Analizing Cluster 5

# %%
cluster_df = pd.read_csv('clustering_v2.csv')

# %%
cluster_5 = cluster_df[cluster_df['K=8 Cluster Labels'] == 5]
cluster_5
# Out:
#        sembrada  cosechada  siniestrada  volumenproduccion    latitud  \
# 225     19430.0    19430.0          0.0          221502.00  28.406312
# 255      4657.0     4657.0          0.0          201112.75  25.570107
# 272     11770.0    11770.0          0.0          182505.62  25.039080
# 303     13960.0    13960.0          0.0          184272.00  22.771900
# 326     16317.0    16317.0          0.0          221421.69  28.764943
# ...         ...        ...          ...                ...        ...
# 11234     180.0        0.0        180.0               0.00  23.129818
# 11235     200.0        0.0        200.0               0.00  23.129818
# 11236     230.0        0.0        230.0               0.00  22.931344
# 11237     352.0        0.0        352.0               0.00  22.323209
# 11248      10.0        0.0         10.0               0.00  23.301759
#
#          longitud  altitud  cicloproductivo_Otoño-Invierno  \
# 225   -106.866044   2062.0                               0
# 255   -103.496417   1130.0                               1
# 272   -105.420945   1730.0                               0
# 303   -103.567233   1889.0                               0
# 326   -107.253622   2023.0                               0
# ...           ...      ...                             ...
# 11234 -101.113352   2019.0                               1
# 11235 -101.113352   2019.0                               0
# 11236 -101.094629   1788.0                               1
# 11237 -100.266649   1106.0                               1
# 11248  -99.547539   1263.0                               1
#
#        cicloproductivo_Perennes  cicloproductivo_Primavera-Verano  \
# 225                           0                                 1
# 255                           0                                 0
# 272                           0                                 1
# 303                           0                                 1
# 326                           0                                 1
# ...                         ...                               ...
# 11234                         0                                 0
# 11235                         0                                 1
# 11236                         0                                 0
# 11237                         0                                 0
# 11248                         0                                 0
#
#        modalidad_Riego  modalidad_Temporal  cultivo_Avena forrajera en verde  \
# 225                  0                   1                                 1
# 255                  1                   0                                 1
# 272                  0                   1                                 1
# 303                  0                   1                                 1
# 326                  0                   1                                 1
# ...                ...                 ...                               ...
# 11234                0                   1                                 1
# 11235                0                   1                                 1
# 11236                0                   1                                 1
# 11237                0                   1                                 1
# 11248                0                   1                                 1
#
#        cultivo_Frijol  cultivo_Maíz grano  cultivo_Pastos y praderas  \
# 225                 0                   0                          0
# 255                 0                   0                          0
# 272                 0                   0                          0
# 303                 0                   0                          0
# 326                 0                   0                          0
# ...               ...                 ...                        ...
# 11234               0                   0                          0
# 11235               0                   0                          0
# 11236               0                   0                          0
# 11237               0                   0                          0
# 11248               0                   0                          0
#
#        cultivo_Tomate rojo (jitomate)  K=8 Cluster Labels  rendimiento  \
# 225                                 0                   5        11.40
# 255                                 0                   5        43.19
# 272                                 0                   5        15.51
# 303                                 0                   5        13.20
# 326                                 0                   5        13.57
# ...                               ...                 ...          ...
# 11234                               0                   5         0.00
# 11235                               0                   5         0.00
# 11236                               0                   5         0.00
# 11237                               0                   5         0.00
# 11248                               0                   5         0.00
#
#                 estado
# 225          Chihuahua
# 255            Durango
# 272            Durango
# 303          Zacatecas
# 326          Chihuahua
# ...                ...
# 11234  San Luis Potosí
# 11235  San Luis Potosí
# 11236  San Luis Potosí
# 11237  San Luis Potosí
# 11248       Tamaulipas
#
# [1340 rows x 20 columns]

# %%
plt.figure(figsize=(10, 7))
sns.set(style = 'whitegrid')  
sns.stripplot(x="rendimiento", y="estado", jitter=0.05, data=cluster_5)
# Out:
# <AxesSubplot:xlabel='rendimiento', ylabel='estado'>

# %% [markdown]
# ### Group the dataframe to identify which is the predominant crop

# %%
cluster_5.groupby(['K=8 Cluster Labels'])['cultivo_Avena forrajera en verde','cultivo_Frijol',
                              'cultivo_Maíz grano','cultivo_Pastos y praderas',
                              'cultivo_Tomate rojo (jitomate)'].mean()
# Out:
# <ipython-input-7-ba5e9cc618cb>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   cluster_5.groupby(['K=8 Cluster Labels'])['cultivo_Avena forrajera en verde','cultivo_Frijol',
#                     cultivo_Avena forrajera en verde  cultivo_Frijol  \
# K=8 Cluster Labels
# 5                                                  1               0
#
#                     cultivo_Maíz grano  cultivo_Pastos y praderas  \
# K=8 Cluster Labels
# 5                                    0                          0
#
#                     cultivo_Tomate rojo (jitomate)
# K=8 Cluster Labels
# 5                                                0

# %% [markdown]
# #### We can see that for the cluster 5 the principal crop is 'Avena forrajera en verde'

# %%
cluster5_cultivo=pd.DataFrame(cluster_6.groupby(['estado'])['cultivo_Avena forrajera en verde'].sum())

# %%
cluster5_cultivo
# Out:
#                  cultivo_Avena forrajera en verde
# estado
# Aguascalientes                                 21
# Chihuahua                                      85
# Coahuila                                       63
# Durango                                        82
# Guanajuato                                     46
# Guerrero                                        2
# Hidalgo                                       102
# Jalisco                                        99
# Michoacán                                     152
# Morelos                                         6
# México                                        186
# Nuevo León                                     26
# Oaxaca                                         37
# Puebla                                        104
# Querétaro                                      16
# San Luis Potosí                                70
# Sonora                                          1
# Tamaulipas                                      6
# Tlaxcala                                      105
# Veracruz                                       14
# Zacatecas                                     117

# %%
cluster_5_g=cluster_5.groupby(['estado'])['cicloproductivo_Otoño-Invierno','cicloproductivo_Perennes',
                              'cicloproductivo_Primavera-Verano','modalidad_Riego',
                              'modalidad_Temporal','rendimiento'].mean()
cluster_5_g
# Out:
# <ipython-input-11-0091e7ddde15>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   cluster_5_g=cluster_5.groupby(['estado'])['cicloproductivo_Otoño-Invierno','cicloproductivo_Perennes',
#                  cicloproductivo_Otoño-Invierno  cicloproductivo_Perennes  \
# estado
# Aguascalientes                         0.428571                       0.0
# Chihuahua                              0.482353                       0.0
# Coahuila                               0.952381                       0.0
# Durango                                0.475610                       0.0
# Guanajuato                             0.652174                       0.0
# Guerrero                               0.500000                       0.0
# Hidalgo                                0.333333                       0.0
# Jalisco                                0.777778                       0.0
# Michoacán                              0.578947                       0.0
# Morelos                                0.000000                       0.0
# México                                 0.295699                       0.0
# Nuevo León                             0.846154                       0.0
# Oaxaca                                 0.621622                       0.0
# Puebla                                 0.288462                       0.0
# Querétaro                              0.687500                       0.0
# San Luis Potosí                        0.471429                       0.0
# Sonora                                 0.000000                       0.0
# Tamaulipas                             0.833333                       0.0
# Tlaxcala                               0.419048                       0.0
# Veracruz                               0.357143                       0.0
# Zacatecas                              0.435897                       0.0
#
#                  cicloproductivo_Primavera-Verano  modalidad_Riego  \
# estado
# Aguascalientes                           0.571429         0.666667
# Chihuahua                                0.517647         0.529412
# Coahuila                                 0.047619         0.571429
# Durango                                  0.524390         0.597561
# Guanajuato                               0.347826         0.782609
# Guerrero                                 0.500000         0.500000
# Hidalgo                                  0.666667         0.539216
# Jalisco                                  0.222222         0.666667
# Michoacán                                0.421053         0.526316
# Morelos                                  1.000000         0.000000
# México                                   0.704301         0.505376
# Nuevo León                               0.153846         0.269231
# Oaxaca                                   0.378378         0.918919
# Puebla                                   0.711538         0.538462
# Querétaro                                0.312500         0.812500
# San Luis Potosí                          0.528571         0.542857
# Sonora                                   1.000000         0.000000
# Tamaulipas                               0.166667         0.166667
# Tlaxcala                                 0.580952         0.704762
# Veracruz                                 0.642857         0.142857
# Zacatecas                                0.564103         0.598291
#
#                  modalidad_Temporal  rendimiento
# estado
# Aguascalientes             0.333333    21.730476
# Chihuahua                  0.470588    18.630706
# Coahuila                   0.428571    22.209841
# Durango                    0.402439    19.213780
# Guanajuato                 0.217391    22.466522
# Guerrero                   0.500000    14.885000
# Hidalgo                    0.460784    24.309412
# Jalisco                    0.333333    22.371818
# Michoacán                  0.473684    16.016118
# Morelos                    1.000000    29.066667
# México                     0.494624    19.399892
# Nuevo León                 0.730769     9.911923
# Oaxaca                     0.081081    22.637838
# Puebla                     0.461538    16.786346
# Querétaro                  0.187500    20.060000
# San Luis Potosí            0.457143    15.844143
# Sonora                     1.000000     6.500000
# Tamaulipas                 0.833333    12.601667
# Tlaxcala                   0.295238    18.321619
# Veracruz                   0.857143    13.548571
# Zacatecas                  0.401709    16.230684

# %%
cluster_5_g = cluster_5_g.loc[:, (cluster_5_g != 0).any(axis=0)]

# %%
cluster_5_g
# Out:
#                  cicloproductivo_Otoño-Invierno  \
# estado
# Aguascalientes                         0.428571
# Chihuahua                              0.482353
# Coahuila                               0.952381
# Durango                                0.475610
# Guanajuato                             0.652174
# Guerrero                               0.500000
# Hidalgo                                0.333333
# Jalisco                                0.777778
# Michoacán                              0.578947
# Morelos                                0.000000
# México                                 0.295699
# Nuevo León                             0.846154
# Oaxaca                                 0.621622
# Puebla                                 0.288462
# Querétaro                              0.687500
# San Luis Potosí                        0.471429
# Sonora                                 0.000000
# Tamaulipas                             0.833333
# Tlaxcala                               0.419048
# Veracruz                               0.357143
# Zacatecas                              0.435897
#
#                  cicloproductivo_Primavera-Verano  modalidad_Riego  \
# estado
# Aguascalientes                           0.571429         0.666667
# Chihuahua                                0.517647         0.529412
# Coahuila                                 0.047619         0.571429
# Durango                                  0.524390         0.597561
# Guanajuato                               0.347826         0.782609
# Guerrero                                 0.500000         0.500000
# Hidalgo                                  0.666667         0.539216
# Jalisco                                  0.222222         0.666667
# Michoacán                                0.421053         0.526316
# Morelos                                  1.000000         0.000000
# México                                   0.704301         0.505376
# Nuevo León                               0.153846         0.269231
# Oaxaca                                   0.378378         0.918919
# Puebla                                   0.711538         0.538462
# Querétaro                                0.312500         0.812500
# San Luis Potosí                          0.528571         0.542857
# Sonora                                   1.000000         0.000000
# Tamaulipas                               0.166667         0.166667
# Tlaxcala                                 0.580952         0.704762
# Veracruz                                 0.642857         0.142857
# Zacatecas                                0.564103         0.598291
#
#                  modalidad_Temporal  rendimiento
# estado
# Aguascalientes             0.333333    21.730476
# Chihuahua                  0.470588    18.630706
# Coahuila                   0.428571    22.209841
# Durango                    0.402439    19.213780
# Guanajuato                 0.217391    22.466522
# Guerrero                   0.500000    14.885000
# Hidalgo                    0.460784    24.309412
# Jalisco                    0.333333    22.371818
# Michoacán                  0.473684    16.016118
# Morelos                    1.000000    29.066667
# México                     0.494624    19.399892
# Nuevo León                 0.730769     9.911923
# Oaxaca                     0.081081    22.637838
# Puebla                     0.461538    16.786346
# Querétaro                  0.187500    20.060000
# San Luis Potosí            0.457143    15.844143
# Sonora                     1.000000     6.500000
# Tamaulipas                 0.833333    12.601667
# Tlaxcala                   0.295238    18.321619
# Veracruz                   0.857143    13.548571
# Zacatecas                  0.401709    16.230684

# %%
cluster5_std=pd.DataFrame(cluster_5.groupby(['estado'])['rendimiento'].std())
cluster5_std
# Out:
#                  rendimiento
# estado
# Aguascalientes     10.782951
# Chihuahua           9.406642
# Coahuila            8.810078
# Durango             7.337197
# Guanajuato          8.985554
# Guerrero            1.322290
# Hidalgo            13.780930
# Jalisco             4.114887
# Michoacán           5.315132
# Morelos             4.742011
# México              3.785579
# Nuevo León          4.519688
# Oaxaca              8.520722
# Puebla              6.678069
# Querétaro           8.245784
# San Luis Potosí     8.144800
# Sonora                   NaN
# Tamaulipas          8.160430
# Tlaxcala            4.740277
# Veracruz            3.488581
# Zacatecas           6.631148

# %%
cluster_5_final = pd.merge(cluster_5_g, cluster5_std, left_index=True, right_index=True)

# %%
cluster_5_final.rename(columns= {'rendimiento_x':'rendimiento_promedio','rendimiento_y':'rendimiento_std'},inplace=True)

# %%
cluster_5_f = pd.merge(cluster_5_final, cluster5_cultivo, left_index=True, right_index=True)

# %%
cluster_5_f.rename(columns= {'cultivo_Avena forrajera en verde':'Numero_cultivos'},inplace=True)

# %%
sns.pairplot(cluster_5_f, height=2.5)

# %%
plt.figure(figsize=(10, 7))
sns.set(style = 'whitegrid')  
sns.stripplot(x="rendimiento", y=cluster_5_g.index, jitter=0.1, linewidth=1, data=cluster_5_g)
# Out:
# <AxesSubplot:xlabel='rendimiento', ylabel='estado'>

# %%
cluster_5_estado = cluster_5_f[cluster_5_f.index == 'Sonora']
cluster_5_estado
# Out:
#         cicloproductivo_Otoño-Invierno  cicloproductivo_Primavera-Verano  \
# estado
# Sonora                             0.0                               1.0
#
#         modalidad_Riego  modalidad_Temporal  rendimiento_promedio  \
# estado
# Sonora              0.0                 1.0                   6.5
#
#         rendimiento_std  Numero_cultivos
# estado
# Sonora              NaN                1

# %%
cluster_5_estado = cluster_5_f[cluster_5_f.index == 'Morelos']
cluster_5_estado
# Out:
#          cicloproductivo_Otoño-Invierno  cicloproductivo_Primavera-Verano  \
# estado
# Morelos                             0.0                               1.0
#
#          modalidad_Riego  modalidad_Temporal  rendimiento_promedio  \
# estado
# Morelos              0.0                 1.0             29.066667
#
#          rendimiento_std  Numero_cultivos
# estado
# Morelos         4.742011                6

# %%
plt.figure(figsize=(10, 7))
sns.set(style = 'whitegrid')  
sns.stripplot(x="rendimiento", y=cluster5_std.index, jitter=0.1, linewidth=1, data=cluster5_std)
# Out:
# <AxesSubplot:xlabel='rendimiento', ylabel='estado'>
