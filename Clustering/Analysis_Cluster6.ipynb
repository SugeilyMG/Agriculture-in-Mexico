# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Analizing Cluster 5

# %%
cluster_df = pd.read_csv('clustering_v2.csv')

# %%
cluster_6 = cluster_df[cluster_df['K=8 Cluster Labels'] == 6]
cluster_6
# Out:
#        sembrada  cosechada  siniestrada  volumenproduccion    latitud  \
# 143    14831.63   14831.63          0.0          394640.38  15.282838
# 151    10211.00   10211.00          0.0          481448.65  19.941389
# 177     7137.94    7137.94          0.0          386593.20  16.367249
# 188    10421.00   10420.00          0.0          215589.80  16.471986
# 197    12716.00   12716.00          0.0          456504.40  18.057503
# ...         ...        ...          ...                ...        ...
# 11099      1.10       1.10          0.0              27.50  20.724991
# 11117      7.50       1.50          0.0              37.50  19.766149
# 11173      1.90       1.90          0.0              20.69  18.747584
# 11211      2.50       2.50          0.0              11.55  22.746782
# 11224     79.00       0.00          0.0               0.00  26.939426
#
#          longitud  altitud  cicloproductivo_Otoño-Invierno  \
# 143    -92.689132     31.0                               0
# 151   -105.245278     36.0                               0
# 177    -94.193848     62.0                               0
# 188    -98.416745     51.0                               0
# 197    -96.397763    155.0                               0
# ...           ...      ...                             ...
# 11099  -89.162199      9.0                               0
# 11117  -97.245526   1881.0                               0
# 11173  -99.676175   1619.0                               0
# 11211 -102.518802   2279.0                               0
# 11224 -105.395077   1592.0                               0
#
#        cicloproductivo_Perennes  cicloproductivo_Primavera-Verano  \
# 143                           1                                 0
# 151                           1                                 0
# 177                           1                                 0
# 188                           1                                 0
# 197                           1                                 0
# ...                         ...                               ...
# 11099                         1                                 0
# 11117                         1                                 0
# 11173                         1                                 0
# 11211                         1                                 0
# 11224                         1                                 0
#
#        modalidad_Riego  modalidad_Temporal  cultivo_Avena forrajera en verde  \
# 143                  0                   1                                 0
# 151                  1                   0                                 0
# 177                  0                   1                                 0
# 188                  0                   1                                 0
# 197                  0                   1                                 0
# ...                ...                 ...                               ...
# 11099                1                   0                                 0
# 11117                1                   0                                 0
# 11173                0                   1                                 0
# 11211                0                   1                                 0
# 11224                1                   0                                 0
#
#        cultivo_Frijol  cultivo_Maíz grano  cultivo_Pastos y praderas  \
# 143                 0                   0                          1
# 151                 0                   0                          1
# 177                 0                   0                          1
# 188                 0                   0                          1
# 197                 0                   0                          1
# ...               ...                 ...                        ...
# 11099               0                   0                          1
# 11117               0                   0                          1
# 11173               0                   0                          1
# 11211               0                   0                          1
# 11224               0                   0                          1
#
#        cultivo_Tomate rojo (jitomate)  K=8 Cluster Labels  rendimiento  \
# 143                                 0                   6        26.61
# 151                                 0                   6        47.15
# 177                                 0                   6        54.16
# 188                                 0                   6        20.69
# 197                                 0                   6        35.90
# ...                               ...                 ...          ...
# 11099                               0                   6        25.00
# 11117                               0                   6        25.00
# 11173                               0                   6        10.89
# 11211                               0                   6         4.62
# 11224                               0                   6         0.00
#
#           estado
# 143      Chiapas
# 151      Jalisco
# 177       Oaxaca
# 188     Guerrero
# 197       Oaxaca
# ...          ...
# 11099    Yucatán
# 11117   Veracruz
# 11173   Guerrero
# 11211  Zacatecas
# 11224  Chihuahua
#
# [1192 rows x 20 columns]

# %%
plt.figure(figsize=(10, 7))
sns.set(style = 'whitegrid')  
sns.stripplot(x="rendimiento", y="estado", jitter=0.05, data=cluster_6)
# Out:
# <AxesSubplot:xlabel='rendimiento', ylabel='estado'>

# %% [markdown]
# ### Group the dataframe to identify which is the predominant crop

# %%
cluster_6.groupby(['K=8 Cluster Labels'])['cultivo_Avena forrajera en verde','cultivo_Frijol',
                              'cultivo_Maíz grano','cultivo_Pastos y praderas',
                              'cultivo_Tomate rojo (jitomate)'].mean()
# Out:
# <ipython-input-7-40b04bba26ed>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   cluster_6.groupby(['K=8 Cluster Labels'])['cultivo_Avena forrajera en verde','cultivo_Frijol',
#                     cultivo_Avena forrajera en verde  cultivo_Frijol  \
# K=8 Cluster Labels
# 6                                                  0               0
#
#                     cultivo_Maíz grano  cultivo_Pastos y praderas  \
# K=8 Cluster Labels
# 6                                    0                          1
#
#                     cultivo_Tomate rojo (jitomate)
# K=8 Cluster Labels
# 6                                                0

# %% [markdown]
# #### We can see that for the cluster 5 the principal crop is 'cultivo_Pastos y praderas	'

# %%
cluster6_cultivo=pd.DataFrame(cluster_6.groupby(['estado'])['cultivo_Pastos y praderas'].sum())

# %%
cluster6_cultivo
# Out:
#                      cultivo_Pastos y praderas
# estado
# Aguascalientes                              17
# Baja California Sur                          1
# Chiapas                                     17
# Chihuahua                                   16
# Coahuila                                    52
# Colima                                      17
# Durango                                     25
# Guanajuato                                  16
# Guerrero                                    64
# Hidalgo                                     32
# Jalisco                                    151
# Michoacán                                   66
# Morelos                                     13
# México                                      83
# Nayarit                                     30
# Nuevo León                                  65
# Oaxaca                                      95
# Puebla                                       8
# Querétaro                                    2
# San Luis Potosí                             43
# Sinaloa                                     31
# Sonora                                      21
# Tamaulipas                                  65
# Tlaxcala                                     7
# Veracruz                                    10
# Yucatán                                    191
# Zacatecas                                   54

# %%
cluster_6_g=cluster_6.groupby(['estado'])['cicloproductivo_Otoño-Invierno','cicloproductivo_Perennes',
                              'cicloproductivo_Primavera-Verano','modalidad_Riego',
                              'modalidad_Temporal','rendimiento'].mean()
cluster_6_g
# Out:
# <ipython-input-46-63037f3f7d01>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   cluster_6_g=cluster_6.groupby(['estado'])['cicloproductivo_Otoño-Invierno','cicloproductivo_Perennes',
#                      cicloproductivo_Otoño-Invierno  cicloproductivo_Perennes  \
# estado
# Aguascalientes                                  0.0                       1.0
# Baja California Sur                             0.0                       1.0
# Chiapas                                         0.0                       1.0
# Chihuahua                                       0.0                       1.0
# Coahuila                                        0.0                       1.0
# Colima                                          0.0                       1.0
# Durango                                         0.0                       1.0
# Guanajuato                                      0.0                       1.0
# Guerrero                                        0.0                       1.0
# Hidalgo                                         0.0                       1.0
# Jalisco                                         0.0                       1.0
# Michoacán                                       0.0                       1.0
# Morelos                                         0.0                       1.0
# México                                          0.0                       1.0
# Nayarit                                         0.0                       1.0
# Nuevo León                                      0.0                       1.0
# Oaxaca                                          0.0                       1.0
# Puebla                                          0.0                       1.0
# Querétaro                                       0.0                       1.0
# San Luis Potosí                                 0.0                       1.0
# Sinaloa                                         0.0                       1.0
# Sonora                                          0.0                       1.0
# Tamaulipas                                      0.0                       1.0
# Tlaxcala                                        0.0                       1.0
# Veracruz                                        0.0                       1.0
# Yucatán                                         0.0                       1.0
# Zacatecas                                       0.0                       1.0
#
#                      cicloproductivo_Primavera-Verano  modalidad_Riego  \
# estado
# Aguascalientes                                    0.0         0.411765
# Baja California Sur                               0.0         1.000000
# Chiapas                                           0.0         0.235294
# Chihuahua                                         0.0         1.000000
# Coahuila                                          0.0         0.519231
# Colima                                            0.0         0.470588
# Durango                                           0.0         0.400000
# Guanajuato                                        0.0         0.875000
# Guerrero                                          0.0         0.421875
# Hidalgo                                           0.0         0.625000
# Jalisco                                           0.0         0.344371
# Michoacán                                         0.0         0.590909
# Morelos                                           0.0         0.153846
# México                                            0.0         0.457831
# Nayarit                                           0.0         0.333333
# Nuevo León                                        0.0         0.446154
# Oaxaca                                            0.0         0.147368
# Puebla                                            0.0         0.250000
# Querétaro                                         0.0         1.000000
# San Luis Potosí                                   0.0         0.302326
# Sinaloa                                           0.0         0.709677
# Sonora                                            0.0         0.952381
# Tamaulipas                                        0.0         0.353846
# Tlaxcala                                          0.0         0.571429
# Veracruz                                          0.0         0.500000
# Yucatán                                           0.0         0.476440
# Zacatecas                                         0.0         0.500000
#
#                      modalidad_Temporal  rendimiento
# estado
# Aguascalientes                 0.588235    36.996471
# Baja California Sur            0.000000    16.000000
# Chiapas                        0.764706    26.845882
# Chihuahua                      0.000000    30.111250
# Coahuila                       0.480769    22.899615
# Colima                         0.529412    23.792941
# Durango                        0.600000    29.674000
# Guanajuato                     0.125000    50.014375
# Guerrero                       0.578125    21.505469
# Hidalgo                        0.375000    61.487187
# Jalisco                        0.655629    33.227219
# Michoacán                      0.409091    34.212424
# Morelos                        0.846154    14.221538
# México                         0.542169    32.148072
# Nayarit                        0.666667    21.590333
# Nuevo León                     0.553846    17.799385
# Oaxaca                         0.852632    24.656105
# Puebla                         0.750000    32.646250
# Querétaro                      0.000000    71.350000
# San Luis Potosí                0.697674    22.446977
# Sinaloa                        0.290323    21.169355
# Sonora                         0.047619    25.880000
# Tamaulipas                     0.646154    16.623385
# Tlaxcala                       0.428571    34.207143
# Veracruz                       0.500000    25.435000
# Yucatán                        0.523560    15.574084
# Zacatecas                      0.500000    33.286111

# %%
cluster_6_g = cluster_6_g.loc[:, (cluster_6_g != 0).any(axis=0)]

# %%
cluster_6_g
# Out:
#                      cicloproductivo_Perennes  modalidad_Riego  \
# estado
# Aguascalientes                            1.0         0.411765
# Baja California Sur                       1.0         1.000000
# Chiapas                                   1.0         0.235294
# Chihuahua                                 1.0         1.000000
# Coahuila                                  1.0         0.519231
# Colima                                    1.0         0.470588
# Durango                                   1.0         0.400000
# Guanajuato                                1.0         0.875000
# Guerrero                                  1.0         0.421875
# Hidalgo                                   1.0         0.625000
# Jalisco                                   1.0         0.344371
# Michoacán                                 1.0         0.590909
# Morelos                                   1.0         0.153846
# México                                    1.0         0.457831
# Nayarit                                   1.0         0.333333
# Nuevo León                                1.0         0.446154
# Oaxaca                                    1.0         0.147368
# Puebla                                    1.0         0.250000
# Querétaro                                 1.0         1.000000
# San Luis Potosí                           1.0         0.302326
# Sinaloa                                   1.0         0.709677
# Sonora                                    1.0         0.952381
# Tamaulipas                                1.0         0.353846
# Tlaxcala                                  1.0         0.571429
# Veracruz                                  1.0         0.500000
# Yucatán                                   1.0         0.476440
# Zacatecas                                 1.0         0.500000
#
#                      modalidad_Temporal  rendimiento
# estado
# Aguascalientes                 0.588235    36.996471
# Baja California Sur            0.000000    16.000000
# Chiapas                        0.764706    26.845882
# Chihuahua                      0.000000    30.111250
# Coahuila                       0.480769    22.899615
# Colima                         0.529412    23.792941
# Durango                        0.600000    29.674000
# Guanajuato                     0.125000    50.014375
# Guerrero                       0.578125    21.505469
# Hidalgo                        0.375000    61.487187
# Jalisco                        0.655629    33.227219
# Michoacán                      0.409091    34.212424
# Morelos                        0.846154    14.221538
# México                         0.542169    32.148072
# Nayarit                        0.666667    21.590333
# Nuevo León                     0.553846    17.799385
# Oaxaca                         0.852632    24.656105
# Puebla                         0.750000    32.646250
# Querétaro                      0.000000    71.350000
# San Luis Potosí                0.697674    22.446977
# Sinaloa                        0.290323    21.169355
# Sonora                         0.047619    25.880000
# Tamaulipas                     0.646154    16.623385
# Tlaxcala                       0.428571    34.207143
# Veracruz                       0.500000    25.435000
# Yucatán                        0.523560    15.574084
# Zacatecas                      0.500000    33.286111

# %%
cluster6_std=pd.DataFrame(cluster_6.groupby(['estado'])['rendimiento'].std())
cluster6_std
# Out:
#                      rendimiento
# estado
# Aguascalientes         34.246203
# Baja California Sur          NaN
# Chiapas                 2.677249
# Chihuahua               8.533247
# Coahuila               11.656962
# Colima                  5.839664
# Durango                19.454284
# Guanajuato             28.966829
# Guerrero                6.556581
# Hidalgo                32.991385
# Jalisco                17.373582
# Michoacán              18.829939
# Morelos                 2.262539
# México                 17.263970
# Nayarit                 4.128116
# Nuevo León              7.629981
# Oaxaca                 10.852507
# Puebla                  7.963834
# Querétaro               5.161880
# San Luis Potosí        24.196245
# Sinaloa                11.313797
# Sonora                 13.902497
# Tamaulipas             13.426181
# Tlaxcala                9.009922
# Veracruz                7.146407
# Yucatán                 7.441042
# Zacatecas              19.000832

# %%
cluster_6_final = pd.merge(cluster_6_g, cluster6_std, left_index=True, right_index=True)

# %%
cluster_6_final.rename(columns= {'rendimiento_x':'rendimiento_promedio','rendimiento_y':'rendimiento_std'},inplace=True)

# %%
cluster_6_f = pd.merge(cluster_6_final, cluster6_cultivo, left_index=True, right_index=True)

# %%
cluster_6_f.rename(columns= {'cultivo_Pastos y praderas':'Numero_cultivos'},inplace=True)

# %%
sns.pairplot(cluster_6_f, height=2.5)

# %%
plt.figure(figsize=(10, 7))
sns.set(style = 'whitegrid')  
sns.stripplot(x="rendimiento", y=cluster_6_g.index, jitter=0.1, linewidth=1, data=cluster_6_g)
# Out:
# <AxesSubplot:xlabel='rendimiento', ylabel='estado'>

# %%
cluster_6_estado = cluster_6_f[cluster_6_f.index == 'Querétaro']
cluster_6_estado
# Out:
#            cicloproductivo_Perennes  modalidad_Riego  modalidad_Temporal  \
# estado
# Querétaro                       1.0              1.0                 0.0
#
#            rendimiento_promedio  rendimiento_std  Numero_cultivos
# estado
# Querétaro                 71.35          5.16188                2

# %%
cluster_6_estado = cluster_6_f[cluster_6_f.index == 'Morelos']
cluster_6_estado
# Out:
#          cicloproductivo_Perennes  modalidad_Riego  modalidad_Temporal  \
# estado
# Morelos                       1.0         0.153846            0.846154
#
#          rendimiento_promedio  rendimiento_std  Numero_cultivos
# estado
# Morelos             14.221538         2.262539               13

# %%
plt.figure(figsize=(10, 7))
sns.set(style = 'whitegrid')  
sns.stripplot(x="rendimiento", y=cluster6_std.index, jitter=0.1, linewidth=1, data=cluster6_std)
# Out:
# <AxesSubplot:xlabel='rendimiento', ylabel='estado'>
